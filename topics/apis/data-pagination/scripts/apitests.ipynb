# %%
import requests

# URL base de la API
base_url = "https://openapi.ariba.com/api/retrieve-contract-workspaces/v1/prod/contractWorkspaces/"

# Tu contractId
contract_id = "CW2228821"

# Parámetros
params = {
    "user": "eperez",
    "passwordAdapter": "PasswordAdapter1",
    "realm": "christushealth"
}

# Encabezados
headers = {
    "Authorization": "Bearer 66675b0a-9905-43f7-91c2-b3a3bd64c1d0",
    "apikey": "Ug67b9rfrkhKrBG1yjNXAOpwwxWxGm7K"
}

# Realizar la solicitud GET
response = requests.get(base_url + contract_id, params=params, headers=headers)

# Imprimir la respuesta
print(response.status_code)
print(response.json())
# Out:
# 200
# {'value': [{'title': 'Contrato MPA ROCHE MX 2023', 'description': '', 'commodities': [], 'regions': [{'uniqueName': 'MEX', 'name': 'Mexico'}], 'departments': [], 'owner': {'uniqueName': 'eperez', 'passwordAdapter': 'PasswordAdapter1', 'name': 'Estephania Pérez', 'emailAddress': 'estephania.perez@christuscei.mx', 'organization': 'Christus Health', 'orgName': 'Christus Health', 'timeZoneID': 'America/Chicago', 'localeID': 'es_MX', 'active': True, 'isSupportAdmin': False, 'orgANId': 'AN01407515616'}, 'contractId': 'CW2228821', 'contractStatus': 'Published', 'supplier': {'name': 'PRODUCTOS ROCHE S.A. DE C.V.', 'systemID': 'ACM_101729925', 'smVendorID': 'S6287764', 'isBlocked': False, 'organizationIDs': [{'domain': 'buyersystemid', 'value': 'acm_101729925'}, {'domain': 'networkid', 'value': 'an11136358770'}, {'domain': 'sap', 'value': 'mex81'}], 'address': {'uniqueName': 'AD31741412', 'phone': '', 'fax': '', 'lines': ['AUTOPISTA MÉXICO - QUERÉTARO KM. 34.5 NAVE 3 INTERIOR 1'], 'city': 'CUAUTITLAN IZCALLI', 'state': 'EDOMEX', 'postalCode': '54740', 'country': 'MX'}}, 'effectiveDate': '2023-05-16T00:00:00.000+0000', 'agreementDate': '2023-07-13T00:00:00.000+0000', 'expirationDate': '2030-05-16T00:00:00.000+0000', 'creationDate': '2023-08-10T22:26:03.819+0000', 'contractAmount': {'amount': 1600000.0, 'currency': 'USD'}, 'version': 1, 'templateId': 'CW2228270', 'amendmentType': '', 'amendmentReason': '', 'origin': 0, 'hierarchicalType': 'MasterAgreement', 'expirationTermType': 'Fixed', 'accessControl': ['Private To Team Members'], 'relatedId': '', 'internalId': 'CW2228821', 'affectedParties': [{'name': 'PRODUCTOS ROCHE S.A. DE C.V.', 'systemID': 'ACM_101729925', 'smVendorID': 'S6287764', 'isBlocked': False, 'organizationIDs': [{'domain': 'buyersystemid', 'value': 'acm_101729925'}, {'domain': 'networkid', 'value': 'an11136358770'}, {'domain': 'sap', 'value': 'mex81'}], 'address': {'uniqueName': 'AD31741412', 'phone': '', 'fax': '', 'lines': ['AUTOPISTA MÉXICO - QUERÉTARO KM. 34.5 NAVE 3 INTERIOR 1'], 'city': 'CUAUTITLAN IZCALLI', 'state': 'EDOMEX', 'postalCode': '54740', 'country': 'MX'}}], 'maximumNumberOfRenewals': 0, 'autoRenewalInterval': 0, 'isTestProject': False, 'lastModified': '2023-08-10T22:28:00.445+0000', 'active': True, 'customFields': [{'fieldId': 'cus_CRGarantias', 'fieldName': 'Garantías', 'fieldDataType': 'textValue', 'booleanValue': None, 'dateValue': None, 'bigDecimalValue': None, 'intValue': None, 'moneyValue': None, 'textValue': [None], 'rank': None, 'multiLineTextValue': None, 'textMultiSelectValue': None, 'percentValue': None, 'urlValue': None, 'userMultiSelectValue': None, 'uomValue': None, 'regionValue': None, 'productValue': None, 'addressValue': None, 'commodityValue': None, 'countryValue': None, 'currencyValue': None, 'departmentValue': None, 'flexMasterDataFieldClassName': None, 'flexMasterDataTypeValue': None, 'uniqueName': None, 'subContent': None, 'userTouched': False, 'templateProperties': ['String1000Field', 'PickListField', 'RequiredField', 'FollowOnProjectSyncOnCreateField', 'SubprojectSyncOnCreateField', 'SubAgreementSyncOnCreateField', 'SubprojectSyncOnChangeField', 'ForceRefreshField', 'RenewalEditField'], 'enumerationValues': None, 'visibilityConstraint': None, 'editabilityConstraint': None, 'validityConstraint': None, 'computedValueConstraint': None, 'helpTip': None, 'instanceOfSubContent': {'flexMasterDataFields': None}, 'customField': True}, {'fieldId': 'cus_CRPerdepago', 'fieldName': 'Periodicidad de Pago', 'fieldDataType': 'textValue', 'booleanValue': None, 'dateValue': None, 'bigDecimalValue': None, 'intValue': None, 'moneyValue': None, 'textValue': [None], 'rank': None, 'multiLineTextValue': None, 'textMultiSelectValue': None, 'percentValue': None, 'urlValue': None, 'userMultiSelectValue': None, 'uomValue': None, 'regionValue': None, 'productValue': None, 'addressValue': None, 'commodityValue': None, 'countryValue': None, 'currencyValue': None, 'departmentValue': None, 'flexMasterDataFieldCl ...
